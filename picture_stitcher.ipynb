# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
img1 = cv2.imread("/home/dcolli23/Downloads/extra_credit_eval_double_lr_no_detections_000642.png")
img2 = cv2.imread("/home/dcolli23/Downloads/extra_credit_eval_double_lr_wonky_box_000792.png")

# %%
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# %%
fig, ax = plt.subplots(nrows=2)
ax[0].imshow(img1)
ax[0].axis("off")
ax[1].imshow(img2)
ax[1].axis("off")
fig.tight_layout()
fig.savefig("extra_credit_poor_performance.png", dpi=300)
